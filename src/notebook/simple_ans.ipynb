# %%
import pandas as pd

# %%
b2nl = pd.read_csv('~/kaggle/rfcx/model/efficient_b2_base_NL/submission_efficient_b2_base_NL_sf.csv')
b2nl.head().iloc[:, 1:]
# Out:
#          s0        s1        s2        s3        s4        s5        s6  \
# 0  0.549197  0.553598  0.550694  0.650136  0.548936  0.560040  0.573925
# 1  0.538151  0.551622  0.553070  0.629738  0.565568  0.544026  0.556141
# 2  0.562968  0.553480  0.550578  0.614935  0.550233  0.557107  0.544571
# 3  0.657217  0.547827  0.546096  0.553835  0.547858  0.547810  0.543978
# 4  0.547613  0.566135  0.548444  0.591726  0.545741  0.557206  0.557287
#
#          s7        s8        s9  ...       s14       s15       s16       s17  \
# 0  0.545423  0.545580  0.561442  ...  0.575465  0.562855  0.548768  0.559921
# 1  0.551300  0.543961  0.550607  ...  0.560666  0.547956  0.691110  0.563652
# 2  0.581494  0.545149  0.554983  ...  0.550942  0.558456  0.551112  0.561286
# 3  0.546453  0.660193  0.547514  ...  0.548847  0.545956  0.547093  0.543643
# 4  0.552182  0.543598  0.555076  ...  0.665878  0.645034  0.553923  0.561673
#
#         s18       s19       s20       s21       s22       s23
# ...

# %%
b0 = pd.read_csv('~/kaggle/rfcx/model/efficient_b0_base_0877/submission_efficient_b0_base_0877.csv')
b0.head().iloc[:, 1:]
# Out:
#          s0        s1        s2        s3        s4        s5        s6  \
# 0  0.548865  0.529908  0.534890  0.708235  0.533684  0.553229  0.539712
# 1  0.514966  0.526210  0.534850  0.698046  0.531079  0.518417  0.536029
# 2  0.552175  0.547308  0.550968  0.678171  0.530955  0.545536  0.526010
# 3  0.709674  0.523118  0.524446  0.547592  0.525875  0.539083  0.531474
# 4  0.519755  0.531208  0.547266  0.663287  0.526062  0.533970  0.569075
#
#          s7        s8        s9  ...       s14       s15       s16       s17  \
# 0  0.525843  0.529263  0.539146  ...  0.547532  0.549101  0.532596  0.538644
# 1  0.526638  0.522375  0.530315  ...  0.538936  0.524105  0.722258  0.534787
# 2  0.602889  0.517193  0.553485  ...  0.525527  0.524705  0.531945  0.538983
# 3  0.537274  0.680468  0.524859  ...  0.525784  0.526257  0.524296  0.526698
# 4  0.540151  0.524441  0.540810  ...  0.708771  0.675631  0.539764  0.533902
#
#         s18       s19       s20       s21       s22       s23
# ...

# %%
b1 = pd.read_csv('~/kaggle/rfcx/model/efficient_b1_base088/submission_efficient_b1_base.csv')
b1.head().iloc[:, 1:]
# Out:
#          s0        s1        s2        s3        s4        s5        s6  \
# 0  0.553258  0.547262  0.530651  0.720047  0.531265  0.541810  0.531953
# 1  0.519762  0.525857  0.530860  0.685949  0.543014  0.522687  0.530428
# 2  0.546766  0.544032  0.557645  0.651274  0.559245  0.545243  0.532574
# 3  0.715190  0.527696  0.525770  0.530409  0.531747  0.526144  0.521042
# 4  0.525241  0.541478  0.538634  0.631233  0.525116  0.540835  0.537691
#
#          s7        s8        s9  ...       s14       s15       s16       s17  \
# 0  0.519858  0.527935  0.540745  ...  0.558279  0.541266  0.531288  0.535026
# 1  0.534265  0.528409  0.520702  ...  0.548789  0.520446  0.720971  0.530487
# 2  0.656025  0.523912  0.537807  ...  0.532614  0.533073  0.535450  0.571033
# 3  0.527479  0.662884  0.532178  ...  0.523251  0.521621  0.527408  0.523153
# 4  0.529582  0.539010  0.536088  ...  0.715764  0.687869  0.533719  0.530602
#
#         s18       s19       s20       s21       s22       s23
# ...

# %%
b2 = pd.read_csv('~/kaggle/rfcx/model/efficient_b2_base_089/submission_efficient_b2_base_0.89.csv')
b2.head().iloc[:, 1:]
# Out:
#          s0        s1        s2        s3        s4        s5        s6  \
# 0  0.542790  0.536328  0.529555  0.709966  0.532237  0.571436  0.536617
# 1  0.523125  0.533594  0.537511  0.693089  0.536275  0.527655  0.528501
# 2  0.551096  0.544335  0.550480  0.676409  0.529033  0.564316  0.530788
# 3  0.708774  0.523222  0.525625  0.538981  0.528819  0.534790  0.521769
# 4  0.530816  0.554075  0.543587  0.627296  0.523864  0.554210  0.549175
#
#          s7        s8        s9  ...       s14       s15       s16       s17  \
# 0  0.525633  0.525437  0.537197  ...  0.574247  0.536440  0.526542  0.530974
# 1  0.532649  0.525690  0.526586  ...  0.560126  0.528807  0.718340  0.537175
# 2  0.619811  0.521097  0.534467  ...  0.545072  0.539368  0.533127  0.550191
# 3  0.527783  0.699644  0.527684  ...  0.544654  0.530787  0.523681  0.524830
# 4  0.542756  0.525775  0.535758  ...  0.711158  0.676278  0.534990  0.540062
#
#         s18       s19       s20       s21       s22       s23
# ...

# %%
resnest = pd.read_csv('~/kaggle/rfcx/model/resnest_sed_base_0886/submission_resnest_base.csv')
resnest.head()
# Out:
#   recording_id        s0        s1        s2        s3        s4        s5  \
# 0    000316da7  0.544856  0.534211  0.534013  0.708380  0.523784  0.551905
# 1    003bc2cb2  0.515631  0.533964  0.527642  0.689440  0.522225  0.523529
# 2    0061c037e  0.543572  0.536931  0.527942  0.664425  0.522068  0.546358
# 3    010eb14d3  0.710392  0.535506  0.534468  0.545330  0.531508  0.532737
# 4    011318064  0.524907  0.547543  0.550641  0.660996  0.522163  0.536929
#
#          s6        s7        s8  ...       s14       s15       s16       s17  \
# 0  0.526293  0.541955  0.524090  ...  0.554542  0.543963  0.533101  0.544309
# 1  0.527266  0.536785  0.523939  ...  0.539323  0.531059  0.722904  0.536333
# 2  0.525466  0.676033  0.517744  ...  0.534357  0.532726  0.533845  0.554257
# 3  0.527585  0.526911  0.657858  ...  0.527184  0.528377  0.527366  0.525256
# 4  0.566618  0.537931  0.532866  ...  0.708481  0.704023  0.542841  0.541052
#
# ...

# %%
b3 = pd.read_csv('~/kaggle/rfcx/model/efficient_b3_no_sed/submission_efficient_b3_nosed.csv')
b3.head().iloc[:, 1:]
# Out:
#          s0        s1        s2        s3        s4        s5        s6  \
# 0  0.028959  0.003929  0.003294  0.885744  0.001550  0.018004  0.002857
# 1  0.000972  0.010299  0.011457  0.560270  0.005889  0.000967  0.000833
# 2  0.005544  0.004498  0.010887  0.390012  0.000823  0.006671  0.005724
# 3  0.982014  0.001290  0.002040  0.001559  0.002317  0.002500  0.001038
# 4  0.002784  0.001221  0.004489  0.258539  0.002510  0.018933  0.004407
#
#          s7        s8        s9  ...       s14       s15       s16       s17  \
# 0  0.000461  0.004091  0.005080  ...  0.016975  0.018629  0.012515  0.003517
# 1  0.002487  0.001503  0.000711  ...  0.009069  0.002096  0.993323  0.002552
# 2  0.165153  0.000534  0.002176  ...  0.000929  0.004518  0.016565  0.028847
# 3  0.001075  0.833608  0.000995  ...  0.001642  0.002495  0.002080  0.000739
# 4  0.001393  0.002437  0.001394  ...  0.939197  0.433244  0.005967  0.007248
#
#         s18       s19       s20       s21       s22       s23
# ...

# %%
ave = (b3.iloc[:, 1:]*0.27 + b1.iloc[:, 1:]*0.23 + b2.iloc[:, 1:]*0.27 + resnest.iloc[:, 1:]*0.23)

# %%
b3.iloc[:, 1:] = ave
b3
# Out:
#      recording_id        s0        s1        s2        s3        s4        s5  \
# 0       000316da7  0.406938  0.394608  0.388742  0.759380  0.386784  0.410703
# 1       003bc2cb2  0.379646  0.390610  0.391677  0.654746  0.391389  0.383358
# 2       0061c037e  0.401071  0.396807  0.401254  0.590545  0.391763  0.405235
# 3       010eb14d3  0.784397  0.386155  0.386324  0.393366  0.387955  0.388611
# 4       011318064  0.385606  0.400405  0.398514  0.536388  0.382995  0.402634
# ...           ...       ...       ...       ...       ...       ...       ...
# 1987    ff68f3ac3  0.457765  0.384463  0.394807  0.480340  0.422200  0.664400
# 1988    ff973e852  0.386845  0.385109  0.385733  0.478023  0.382413  0.409982
# 1989    ffa5cf6d6  0.387471  0.409564  0.405471  0.730157  0.382049  0.398642
# 1990    ffa88cbb8  0.384078  0.544730  0.401192  0.758983  0.381776  0.407702
# 1991    ffda5d7b3  0.378372  0.381924  0.769408  0.537661  0.376440  0.392912
#
# ...

# %%
b3.to_csv('submission_simpe_average.csv', index=False)
